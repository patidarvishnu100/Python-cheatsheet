# %%
item = [ "apple", "banana", "cherry" ]

print(item)
# Out:
# ['apple', 'banana', 'cherry']

# %%
item = [ "apple", 25, True, 5.5, "apple"]
print(item)
# Out:
# ['apple', 25, True, 5.5, 'apple']

# %%
print(item[3])
# Out:
# 5.5

# %%
item = ["vishnu", 33, "Ai engineer", 105000]
print(item)
# Out:
# ['vishnu', 33, 'Ai engineer', 105000]

# %%
# list methods


"""list methods in python"""
# Out:
# 'list methods in python'

# %%
# list methods in python

item.append("city")

# %%
item
# Out:
# ['vishnu', 33, 'Ai engineer', 105000, 'indore', 'city', 'city']

# %%
# python extend method


item1 = ["apple", "banana", "cherry"]
item2 = ["orange", "kiwi", "melon"]


item1.extend(item2)
item1
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon']

# %%
# insert method in python

item1 = ["apple", "banana", "cherry"]

item1.insert(1, "orange")
item1
# Out:
# ['apple', 'orange', 'banana', 'cherry']

# %%
# remove method in python

item1 = ["apple", "banana", "cherry"]
item1.remove("banana")
item1
# Out:
# ['apple', 'cherry']

# %%
# pop method in python

items = ["apple", "banana", "cherry"]
items.pop(1)
items
# Out:
# ['apple', 'cherry']

# %%
# clear method in python
items = ["apple", "banana", "cherry"]
items.clear()

items
# Out:
# []

# %%
# sort method in python
item = [567,527,4,2,8,0,35,1,3,5,6,7,8,9]

item.sort()
item
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8, 8, 9, 35, 527, 567]

# %%
# reverse method in python
item = [567,527,4,2,8,0,35,1,3,5,6,7,8,9]

item.reverse()
item
# Out:
# [9, 8, 7, 6, 5, 3, 1, 35, 0, 8, 2, 4, 527, 567]

# %%
# copy method in python

a = [1,2,3,4,5,6,7,8,9]


b = a.copy()
b
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# count method in python

item = [567,527,4,2,8,0,35,1,3,5,6,7,8,9,8]

item.count(567)
# Out:
# 1

# %%
# index method in python

item = [567,527,4,2,8,0,35,1,3,5,6,7,8,9]

item.index(0)
# Out:
# 5

# %%
# slicing in python

a = [1,2,3,4,5,6,7,8,9]
print(a[2])
# Out:
# 3

# %%
a[0:8:2]
# Out:
# [1, 3, 5, 7]

# %%
a[-3:-1]
# Out:
# [7, 8]

# %%
print(a[-2])
# Out:
# 8

# %%
print(a[3:7])
# Out:
# [4, 5, 6, 7]

# %%
print(a[3:7:2])

# %%
name = "vishnu"

name[-1]
# Out:
# 'u'

# %% [markdown]
# # tuple

# %%
# tuple in python

item = ("apple", "banana", "cherry", "banana")
print(item)
# Out:
# ('apple', 'banana', 'cherry', 'banana')

# %%
item[0]
# Out:
# 'apple'

# %%
item[0:2]
# Out:
# ('apple', 'banana')

# %%
# count method in tuple

item.count("banana")
# Out:
# 2

# %%
# index methods in tuple

item.index("cherry")
# Out:
# 2

# %% [markdown]
# # set in python

# %%
my_set = set()

print(my_set)
# Out:
# set()

# %%
my_set2 = set()
print(type(my_set2))
# Out:
# <class 'set'>

# %%
item = {"banana", "apple", "banana", "cherry"}
print(item)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
# methods in set

# %%
my_set = {"vishnu", 33, "Ai engineer"}
print(my_set)
# Out:
# {33, 'vishnu', 'Ai engineer'}

# %%
my_set.add("python")

# %%
print(my_set)
# Out:
# {33, 'python', 'vishnu', 'Ai engineer'}

# %%
# remove methods in set

my_set.remove(33)
my_set
# Out:
# {'vishnu'}

# %%
# discard method in set
my_set = {"vishnu", 33, "Ai engineer"}
my_set.discard("python")
my_set
# Out:
# {33, 'Ai engineer', 'vishnu'}

# %%
print(my_set)
# Out:
# {33, 'vishnu', 'Ai engineer'}

# %%
my_set.pop()
# Out:
# 33

# %%
my_set.pop()
# Out:
# 'vishnu'

# %%
my_set
# Out:
# {'Ai engineer'}

# %%
# clear methods in set

my_set.clear()

# %%
my_set
# Out:
# set()

# %%
# union and intersection in set

s1 = {"vishnu", 33}
s2 = {"ai engineer", "python", 33}

s1.union(s2)
# Out:
# {33, 'ai engineer', 'python', 'vishnu'}

# %%
s1 = {"vishnu", 33}
s2 = {"ai engineer", "python", 33}

s1.intersection(s2)
# Out:
# {33}

# %%
# differnce in set 

s1 = {"vishnu", 33, "patidar"}
s2 = {"ai engineer", "python", 33}

s1.difference(s2)
# Out:
# {'patidar', 'vishnu'}

# %%
# update method in set 

s1 = {"vishnu", 33, "patidar"}
s2 = {"ai engineer", "python", 33}

s1.update(s2)

# %%
s1
# Out:
# {33, 'ai engineer', 'patidar', 'python', 'vishnu'}

# %% [markdown]
# # Dictionary in python

# %%
dict1 = {
    "name":"vishnu",
    "age": 33,
    "salary": 100000,
    "city": "indore"
}

# %%
print(dict1)
# Out:
# {'name': 'vishnu', 'age': 33, 'salary': 100000, 'city': 'indore'}

# %%
print(type(dict1))
# Out:
# <class 'dict'>

# %%
dict1["country"] = "india"

# %%
dict1
# Out:
# {'name': 'vishnu',
#  'age': 33,
#  'salary': 100000,
#  'city': 'indore',
#  'country': 'india'}

# %%
dict1["name"] = "rakesh"

# %%
dict1
# Out:
# {'name': 'rakesh',
#  'age': 33,
#  'salary': 100000,
#  'city': 'indore',
#  'country': 'india'}

# %%
dict1["graduation"] = True

dict1
# Out:
# {'name': 'rakesh',
#  'age': 33,
#  'salary': 100000,
#  'city': 'indore',
#  'country': 'india',
#  'graduation': True}

# %%
# methods in dictionary 

# keys() method in dictionary


dict1 = {
    "name":"vishnu",
    "age": 33,
    "salary": 100000,
    "city": "indore"
}
print(dict1)
# Out:
# {'name': 'vishnu', 'age': 33, 'salary': 100000, 'city': 'indore'}

# %%
dict1.keys()
# Out:
# dict_keys(['name', 'age', 'salary', 'city'])

# %%
# values in dictionary

dict1.values()
# Out:
# dict_values(['vishnu', 33, 100000, 'indore'])

# %%
dict1
# Out:
# {'name': 'vishnu', 'age': 33, 'salary': 100000, 'city': 'indore'}

# %%
# Out:
# 'vishnu'

# %%
student1 = {
    "name":"vishnu",
    "age": 33,
    "salary": 100000,
    "city": "indore"
}

student2 = {
    "name":"rakesh",
    "age": 35,
    "salary": 800000,
    "city": "mumbai"
}

# %%
print(student1["name"])
print(student2["age"])
# Out:
# vishnu
# 35

# %%
student1["country"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 student1["country"]
#
# KeyError: 'country'

# %%
print(student1.get("country"))
# Out:
# None

# %%
student = {"name": "vishnu"}
student2 = {"age": 35}

student2.update(student)

# %%
student2
# Out:
# {'age': 35, 'name': 'vishnu'}

# %%
student2.popitem()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 student2.popitem()
#
# KeyError: 'popitem(): dictionary is empty'

# %%
student2
# Out:
# {}

# %%
student1 = {"name":"vishnu"}

student1.clear()
student1
# Out:
# {}

# %% [markdown]
# # advance of data structures

# %%
a = [1,2,3,4]
print(a)
# Out:
# [1, 2, 3, 4]

# %%
a = [1,2,3,[4,5]]
print(a)
# Out:
# [1, 2, 3, [4, 5]]

# %%
list = [(1,2), (3,4)]
print(list)
# Out:
# [(1, 2), (3, 4)]

# %%
list_set = [{1,2,3}, 1,2,3]

# %%
list_set
# Out:
# [{1, 2, 3}, 1, 2, 3]

# %%
a = [1,2,3,4,4]
print(a)
# Out:
# [1, 2, 3, 4, 4]

# %%
print(type(a))
# Out:
# <class 'list'>

# %%
a_set = set(a)

# %%
print(type(a_set))
# Out:
# <class 'set'>

# %%
print(a_set)
# Out:
# {1, 2, 3, 4}

# %%
set_to_list = list(a_set)
print(set_to_list)
print(type(set_to_list))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 set_to_list = list(a_set)
#       2 print(set_to_list)
#       3 print(type(set_to_list))
#
# TypeError: 'list' object is not callable

# %%
set_2 = {2,3,4,5}

set_to_list = list(set_2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 3
#       1 set_2 = {2,3,4,5}
#       2
# ----> 3 set_to_list = list(set_2)
#
# TypeError: 'list' object is not callable
